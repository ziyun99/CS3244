# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/y3s2/CS3244 ML Project/Dataset
# Out:
# /content/drive/MyDrive/y3s2/CS3244 ML Project/Dataset

# %%
# !git clone https://github.com/ziyun99/CS3244.git
# Out:
# Cloning into 'CS3244'...
# ...

# %%
# !git config --global user.email "e0313671@u.nus.edu"
# !git config --global user.name "ziyun99"

# %%
# !git add .
# !git commit -m "initial data"
# Out:
# ^C
# On branch master
# Changes not staged for commit:
# 	modified:   CS3244.ipynb
# 	deleted:    Dataset/food/compost1.jpg
# 	deleted:    Dataset/food/compost100.jpg
# 	deleted:    Dataset/food/compost101.jpg
# 	deleted:    Dataset/food/compost102.jpg
# 	deleted:    Dataset/food/compost103.jpg
# 	deleted:    Dataset/food/compost104.jpg
# 	deleted:    Dataset/food/compost105.jpg
# 	deleted:    Dataset/food/compost107.jpg
# 	deleted:    Dataset/food/compost108.jpg
# 	deleted:    Dataset/food/compost109.jpg
# 	deleted:    Dataset/food/compost11.jpg
# 	deleted:    Dataset/food/compost110.jpg
# 	deleted:    Dataset/food/compost111.jpg
# 	deleted:    Dataset/food/compost112.jpg
# 	deleted:    Dataset/food/compost113.jpg
# 	deleted:    Dataset/food/compost116.jpg
# 	deleted:    Dataset/food/compost12.jpg
# 	deleted:    Dataset/food/compost120.jpg
# 	deleted:    Dataset/food/compost121.jpg
# 	deleted:    Dataset/food/compost122.jpg
# 	deleted:    Dataset/food/compost123.jpg
# ...

# %%
# %cd /content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244
# !git status
# Out:
# /content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244

# %%
# !git remote remove origin 
# !git remote add origin https://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@github.com/ziyun99/CS3244.git
# !git remote add origin https://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@github.com/ziyun99/CS3244.git
# !git push origin master
# Out:
# Counting objects: 835, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (835/835), done.
# Writing objects: 100% (835/835), 5.28 MiB | 3.48 MiB/s, done.
# Total 835 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ziyun99/CS3244.git
#    04c1203..c827b8e  master -> master

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
import numpy as np
from IPython.display import display
from PIL import Image
import os

# %%
from PIL import Image
import os
 
folder = "/content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244/Dataset/"
# folder = "/content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244/compostnet-dataset-resized"
w = 224
h = 224
for root, dirs, files in os.walk(folder):
  # print(f)
  for name in files:
      fname = os.path.join(root, name)
      exts = ['.jpg', '.jpeg','.png']
      for ext in exts:
        if ext in fname:
          # print(fname)
          image = Image.open(fname)
          # image.show()
          # print(fname)
          # print(image.size)
          # display(image)
          width, height = image.size 
          print(image.size)
          if width != 224 or height != 224:
            print(fname)
            break
          # if width > height:
          #  image.thumbnail((image.size[0], 224), Image.ANTIALIAS)
          # else:
          #  image.thumbnail((224, image.size[1]), Image.ANTIALIAS)
          # print(image.size)
          # # display(image)

          # width, height = image.size   # Get dimensions

          # left = (width - 224)/2
          # top = (height - 224)/2
          # right = (width + 224)/2
          # bottom = (height + 224)/2

          # # Crop the center of the image
          # if width > 224 and height > 224:
          #   image = image.crop((left, top, right, bottom))
          # else:
          #   image =image.resize((224, 224), Image.ANTIALIAS)

          # print(image.size)
          # image = image.convert('RGB')
          # # display(image)

          # image.save(fname, "JPEG")
# Out:
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# ...

# %%
import os
folder = "/content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244/compostnet-dataset-resized"
# folder = "/content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244/Dataset/"
for root, dirs, files in os.walk(folder):
  # for dirnames in dirs:
    # dirname = os.path.join(root, dirnames)
    # print(dirname)
  if len(files) > 0:
    print(files[0], len(files))
  # for name in files:
  #     fname = os.path.join(root, name)
  #     # print(fname)
  #     if ".webp" in fname:
  #       print(fname)
  #       os.remove(fname)
# Out:
# .DS_Store 1
# paper283.jpg 594
# metal296.jpg 411
# cardboard233.jpg 403
# trash118.jpg 184
# glass239.jpg 501
# plastic391.jpg 482
# compost12.jpg 178
# fabric 3.png 39
# battery_10.jpg 206

# %%
# 
# %cd /content/drive/MyDrive/y3s2/CS3244 ML Project/CS3244
# !wget https://github.com/garythung/trashnet/blob/master/data/dataset-resized.zip
# !unzip /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/Dataset/compostnet-dataset-resized.zip
# !rm -rf /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/__MACOSX
# !cp -r /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/Dataset/recyclable/fabric /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/compostnet-dataset-resized/
# !cp -r /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/Dataset/hazardous /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/compostnet-dataset-resized
# !rm /content/drive/MyDrive/y3s2/CS3244\ ML\ Project/CS3244/compostnet-dataset-resized/hazardous_1/*.zip

# %%
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.losses import categorical_crossentropy
from keras.optimizers import adam, sgd
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
